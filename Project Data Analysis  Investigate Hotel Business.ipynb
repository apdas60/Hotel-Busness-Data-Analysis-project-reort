# %% [markdown]
# # LOAD REQUERED LIBRARY

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # LOAD CSV FILE

# %%
df=pd.read_csv('hotel_bookings.csv')

# %% [raw]
#  Before starting to solve this project , the first step that must be done is to prepare the raw data into clean and ready-to-process data, we have to do data pre-processing, which is to handle various data problems such as empty data, inappropriate data, to identify data that is not needed. So the steps taken are as follows:

# %% [markdown]
# # READ DATA

# %%
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
df.sample(10)
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 94477     City Hotel            0        160               2016
# 102655    City Hotel            0         66               2016
# 29517   Resort Hotel            0         20               2016
# 22922   Resort Hotel            0         39               2016
# 15621   Resort Hotel            1        243               2015
# 52206     City Hotel            1        330               2016
# 75495     City Hotel            1        341               2015
# 36310   Resort Hotel            0          2               2017
# 74922     City Hotel            1        136               2015
# 117520    City Hotel            0          1               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 94477              August                        32
# 102655           November                        49
# 29517             October                        44
# ...

# %% [markdown]
# # check data type and null values from dataset using info

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %% [raw]
# The column ‘children’ , ‘city’ , ‘agent’ and ‘company’ have null values, and we need to adjust data type from ‘children’, ‘agent’ and ‘company’ because the column should be integer instead of float.

# %%
df.isnull().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %% [markdown]
# # PERCENTAGE OF NULL VALUES

# %%
df.isnull().sum()*100/len(df)
# Out:
# hotel                              0.000000
# is_canceled                        0.000000
# lead_time                          0.000000
# arrival_date_year                  0.000000
# arrival_date_month                 0.000000
# arrival_date_week_number           0.000000
# arrival_date_day_of_month          0.000000
# stays_in_weekend_nights            0.000000
# stays_in_week_nights               0.000000
# adults                             0.000000
# children                           0.003350
# babies                             0.000000
# meal                               0.000000
# country                            0.408744
# market_segment                     0.000000
# distribution_channel               0.000000
# is_repeated_guest                  0.000000
# previous_cancellations             0.000000
# previous_bookings_not_canceled     0.000000
# reserved_room_type                 0.000000
# assigned_room_type                 0.000000
# ...

# %% [raw]
# From above percent null values Company has 94% null values so either we can drop the column or fill the column

# %% [raw]
# To handle null values from column ‘children’, ‘city’, ‘agent’, and ‘company’. Null values in ‘children’ column could mean 0 children, Null values in ‘city’ column can be seen as Unknown city, According to the research paper attached to the dataset, null values in ‘agent’ and ‘company’ means the booking did not came from a travel agent. we will replace it with 0, which means ‘Not applicable’.

# %% [markdown]
# # HANDLE NULL VALUES

# %%
df['children'] = df['children'].fillna(0)
df['country']=df['country'].fillna('unknown')
df['agent'] = df['agent'].fillna(0)
df['company'] = df['company'].fillna(0)

# %%
df.isnull().sum()
# Out:
# hotel                             0
# is_canceled                       0
# lead_time                         0
# arrival_date_year                 0
# arrival_date_month                0
# arrival_date_week_number          0
# arrival_date_day_of_month         0
# stays_in_weekend_nights           0
# stays_in_week_nights              0
# adults                            0
# children                          0
# babies                            0
# meal                              0
# country                           0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# reserved_room_type                0
# assigned_room_type                0
# booking_changes                   0
# deposit_type                      0
# agent                             0
# company                           0
# days_in_waiting_list              0
# ...

# %% [markdown]
# # HANDLE DUPLICATE VALULES

# %%
df.duplicated().sum()
# Out:
# 31994

# %% [raw]
# As we can see this dataset have duplicated data and we need to drop duplicated data

# %% [markdown]
# # DROP DUPLICATE DATA

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # CHECK DATATYPES

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 87396 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   hotel                           87396 non-null  object
#  1   is_canceled                     87396 non-null  int64
#  2   lead_time                       87396 non-null  int64
#  3   arrival_date_year               87396 non-null  int64
#  4   arrival_date_month              87396 non-null  object
#  5   arrival_date_week_number        87396 non-null  int64
#  6   arrival_date_day_of_month       87396 non-null  int64
#  7   stays_in_weekend_nights         87396 non-null  int64
#  8   stays_in_week_nights            87396 non-null  int64
#  9   adults                          87396 non-null  int64
#  10  children                        87396 non-null  float64
#  11  babies                          87396 non-null  int64
# ...

# %% [markdown]
# # We fix the data type from ‘children’, ‘agent’ and ‘company’ to integer

# %%
df['children'] = df['children'].astype('int64')
df['agent'] = df['agent'].astype('int64')
df['company'] = df['company'].astype('int64')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 87396 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   hotel                           87396 non-null  object
#  1   is_canceled                     87396 non-null  int64
#  2   lead_time                       87396 non-null  int64
#  3   arrival_date_year               87396 non-null  int64
#  4   arrival_date_month              87396 non-null  object
#  5   arrival_date_week_number        87396 non-null  int64
#  6   arrival_date_day_of_month       87396 non-null  int64
#  7   stays_in_weekend_nights         87396 non-null  int64
#  8   stays_in_week_nights            87396 non-null  int64
#  9   adults                          87396 non-null  int64
#  10  children                        87396 non-null  int64
#  11  babies                          87396 non-null  int64
# ...

# %%
df['reservation_status_date']=pd.to_datetime(df['reservation_status_date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 87396 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   hotel                           87396 non-null  object
#  1   is_canceled                     87396 non-null  int64
#  2   lead_time                       87396 non-null  int64
#  3   arrival_date_year               87396 non-null  int64
#  4   arrival_date_month              87396 non-null  object
#  5   arrival_date_week_number        87396 non-null  int64
#  6   arrival_date_day_of_month       87396 non-null  int64
#  7   stays_in_weekend_nights         87396 non-null  int64
#  8   stays_in_week_nights            87396 non-null  int64
#  9   adults                          87396 non-null  int64
#  10  children                        87396 non-null  int64
#  11  babies                          87396 non-null  int64
# ...

# %%
df.describe(include=object)
# Out:
#              hotel arrival_date_month   meal country market_segment  \
# count        87396              87396  87396   87396          87396
# unique           2                 12      5     178              8
# top     City Hotel             August     BB     PRT      Online TA
# freq         53428              11257  67978   27453          51618
#
#        distribution_channel reserved_room_type assigned_room_type  \
# count                 87396              87396              87396
# unique                    5                 10                 12
# top                   TA/TO                  A                  A
# freq                  69141              56552              46313
#
#        deposit_type customer_type reservation_status
# count         87396         87396              87396
# unique            3             4                  3
# top      No Deposit     Transient          Check-Out
# freq          86251         71986              63371

# %%
for col in df.describe(include='object').columns:
    print(col)
    print(df[col].unique())
    print('_'*50)
# Out:
# hotel
# ['Resort Hotel' 'City Hotel']
# __________________________________________________
# arrival_date_month
# ['July' 'August' 'September' 'October' 'November' 'December' 'January'
#  'February' 'March' 'April' 'May' 'June']
# __________________________________________________
# meal
# ['BB' 'FB' 'HB' 'SC' 'Undefined']
# __________________________________________________
# country
# ['PRT' 'GBR' 'USA' 'ESP' 'IRL' 'FRA' 'unknown' 'ROU' 'NOR' 'OMN' 'ARG'
#  'POL' 'DEU' 'BEL' 'CHE' 'CN' 'GRC' 'ITA' 'NLD' 'DNK' 'RUS' 'SWE' 'AUS'
#  'EST' 'CZE' 'BRA' 'FIN' 'MOZ' 'BWA' 'LUX' 'SVN' 'ALB' 'IND' 'CHN' 'MEX'
#  'MAR' 'UKR' 'SMR' 'LVA' 'PRI' 'SRB' 'CHL' 'AUT' 'BLR' 'LTU' 'TUR' 'ZAF'
#  'AGO' 'ISR' 'CYM' 'ZMB' 'CPV' 'ZWE' 'DZA' 'KOR' 'CRI' 'HUN' 'ARE' 'TUN'
#  'JAM' 'HRV' 'HKG' 'IRN' 'GEO' 'AND' 'GIB' 'URY' 'JEY' 'CAF' 'CYP' 'COL'
#  'GGY' 'KWT' 'NGA' 'MDV' 'VEN' 'SVK' 'FJI' 'KAZ' 'PAK' 'IDN' 'LBN' 'PHL'
#  'SEN' 'SYC' 'AZE' 'BHR' 'NZL' 'THA' 'DOM' 'MKD' 'MYS' 'ARM' 'JPN' 'LKA'
# ...

# %%
df.describe()
# Out:
#         is_canceled     lead_time  arrival_date_year  \
# count  87396.000000  87396.000000       87396.000000
# mean       0.274898     79.891368        2016.210296
# std        0.446466     86.052325           0.686102
# min        0.000000      0.000000        2015.000000
# 25%        0.000000     11.000000        2016.000000
# 50%        0.000000     49.000000        2016.000000
# 75%        1.000000    125.000000        2017.000000
# max        1.000000    737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count              87396.000000               87396.000000
# mean                  26.838334                  15.815541
# std                   13.674572                   8.835146
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   27.000000                  16.000000
# 75%                   37.000000                  23.000000
# ...

# %%
df['adr'].plot(kind='box')
# Out:
# <Axes: >

# %%
df=df[df['adr']<5000]

# %% [markdown]
# # DATA ANALYSIS AND VISUALIZATIONS

# %%
df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
cancel_perc=df[ 'is_canceled'].value_counts()

# %%
cancel_perc
# Out:
# 0    63371
# 1    24024
# Name: is_canceled, dtype: int64

# %%
cancel_perc=df[ 'is_canceled'].value_counts(normalize=True)

# %%
cancel_perc*100
# Out:
# 0    72.511013
# 1    27.488987
# Name: is_canceled, dtype: float64

# %%
plt.figure(figsize=(5,4))
plt.title('Reservation Status Count')
plt.bar(['Not cancel','Cancel'],df[ 'is_canceled'].value_counts())
plt.show()

# %%
sns.countplot(x='hotel',hue='is_canceled',palette = "Set2",data=df).set(title='reservation vs cancel')
plt.show()

# %%
df['hotel'].unique()
# Out:
# array(['Resort Hotel', 'City Hotel'], dtype=object)

# %%
resort_hotel=df[df['hotel']=='Resort Hotel']
resort_hotel['is_canceled'].value_counts(normalize=True)
# Out:
# 0    0.765191
# 1    0.234809
# Name: is_canceled, dtype: float64

# %%
city_hotel=df[df['hotel']=='City Hotel']
city_hotel['is_canceled'].value_counts(normalize=True)
# Out:
# 0    0.699628
# 1    0.300372
# Name: is_canceled, dtype: float64

# %% [markdown]
# # Overall the number of hotel bookings each month based on the type of hotel.

# %%
df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
cancel_hotel_month=df.groupby('arrival_date_month')

# %%
cancel_hotel_month['is_canceled'].sum()
# Out:
# arrival_date_month
# April        2409
# August       3623
# December     1378
# February     1415
# January      1038
# July         3198
# June         2354
# March        1829
# May          2442
# November     1054
# October      1642
# September    1642
# Name: is_canceled, dtype: int64

# %%
cancel_hotel_month['is_canceled'].sum().plot(kind='bar').set(title='month vs canceled')
# Out:
# [Text(0.5, 1.0, 'month vs canceled')]

# %% [markdown]
# # which country have canceltaion

# %%
df['country'].value_counts().head(10)
# Out:
# PRT    27452
# GBR    10433
# FRA     8837
# ESP     7252
# DEU     5387
# ITA     3066
# IRL     3016
# BEL     2081
# BRA     1995
# NLD     1911
# Name: country, dtype: int64

# %%
df['country'].value_counts().head(10).plot.pie().set(title='country wise cancelation')
# Out:
# [Text(0.5, 1.0, 'country wise cancelation')]

# %% [markdown]
# # MARKET SEGMENT

# %%
df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
df['market_segment'].value_counts()
# Out:
# Online TA        51618
# Offline TA/TO    13888
# Direct           11804
# Groups            4942
# Corporate         4212
# Complementary      702
# Aviation           227
# Undefined            2
# Name: market_segment, dtype: int64

# %%
df['market_segment'].value_counts().plot.pie()
# Out:
# <Axes: ylabel='market_segment'>

# %% [markdown]
# Around 47% of bookings are made via Online Travel Agents, almost 20% of bookings are made via Offline Travel Agents and less than 20% are Direct bookings without any other agents.Around 47% of bookings are made via Online Travel Agent

# %% [markdown]
# # Year

# %%
df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
df.arrival_date_year.value_counts()
# Out:
# 2016    42390
# 2017    31692
# 2015    13313
# Name: arrival_date_year, dtype: int64

# %%
plt.figure(figsize=(12,6))
sns.barplot(x='arrival_date_year', y='lead_time',hue='is_canceled', data= df, palette='vlag').set(title='Arriving year, Leadtime and Cancelations')
plt.show()

# %% [markdown]
# For all the 3 years, bookings with a lead time less than 100 days have fewer chances of getting canceled, and lead time more than 100 days have more chances of getting canceled.

# %% [markdown]
# # PRICE FACTOR

# %% [markdown]
# average daily rate =  SumOfAllLodgingTransaction/TotalNumberOfStayingNight
#
#  average daily rate per person =  ADR/(Adults+Children)
#
# We will need to find out average daily rate per person

# %%
resort_hotel=resort_hotel.groupby('reservation_status_date')[['adr']].mean()
city_hotel=city_hotel.groupby('reservation_status_date')[['adr']].mean()

# %%
plt.figure(figsize=(20,8))
plt.plot(resort_hotel.index,resort_hotel['adr'],label='Resort hotel')
plt.plot(city_hotel.index,city_hotel['adr'],label='City hotel')
plt.legend(fontsize=20)
plt.show()

# %% [markdown]
# Prices of resort hotel are much higher.
# Prices of city hotel do not fluctuate that much.

# %% [markdown]
# # Summary

# %% [markdown]
# Majority of the hotels booked are city hotel. Definitely need to spend the most targeting fund on those hotel.
# We also realise that the high rate of cancellations can be due high no deposit policies.
# We should also target months between May to Aug. Those are peak months due to the summer period.
# Majority of the guests are from Western Europe. We should spend a significant amount of our budget on those area.
# Given that we do not have repeated guests, we should target our advertisement on guests to increase returning guests.
